# %% [markdown]
# # Advertising Sales Channel Prediction Project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing the required Libraries

# %%
ad_proj = pd.read_csv("Advertising.csv")
ad_proj
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
ad_proj.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
ad_proj.shape
# Out:
# (200, 5)

# %% [markdown]
# Total number of Rows = 200 and Columns = 5

# %%
ad_proj.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# From the above case, there are no null values

# %%
for i in ad_proj.columns:
    print(np.where(ad_proj[i]==0))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([127], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
ad_proj.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %% [markdown]
# From the above case, data type for everything except the 1st row is float

# %%
ad_proj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# From the above case, there are no null values

# %%
ad_proj.value_counts()
# Out:
# Unnamed: 0  TV     radio  newspaper  sales
# 200         232.1  8.6    8.7        13.4     1
# 63          239.3  15.5   27.3       15.7     1
# 73          26.8   33.0   19.3       8.8      1
# 72          109.8  14.3   31.7       12.4     1
# 71          199.1  30.6   38.7       18.3     1
#                                              ..
# 131         0.7    39.6   8.7        1.6      1
# 130         59.6   12.0   43.1       9.7      1
# 129         220.3  49.0   3.2        24.7     1
# 128         80.2   0.0    9.2        8.8      1
# 1           230.1  37.8   69.2       22.1     1
# Length: 200, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# # Scatterplot ---

# %%
ad_proj.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
sns.scatterplot(x="Unnamed: 0", y="sales", data=ad_proj, color="green")
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='sales'>

# %%
sns.scatterplot(x="TV", y="sales", data=ad_proj, color="green")
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %%
sns.scatterplot(x="radio", y="sales", data=ad_proj, color="green")
# Out:
# <AxesSubplot:xlabel='radio', ylabel='sales'>

# %%
sns.scatterplot(x="newspaper", y="sales", data=ad_proj, color="green")
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %% [markdown]
# # Pairing all the plots ---

# %%
pair = sns.pairplot(ad_proj)
pair

# %% [markdown]
# From the above case, the sale value increases in case of TV and radio

# %% [markdown]
# # Describing Dataset ---

# %%
ad_proj.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
plt.figure(figsize=(18,24))
sns.heatmap(round(ad_proj.describe()[1:].transpose(),2), linewidth = 1, annot = True, fmt="f")
plt.xticks(fontsize=15)
plt.yticks(fontsize=10)
plt.title("Variables Summary")
plt.show()

# %% [markdown]
# # Dataset Outcome ---

# %% [markdown]
# Unnamed: 0
#
# 1. Mean = 100.50
# 2. Standard Deviation (std) = 57.88
# 3. Minimum Value (min) = 1
# 4. Maximum Value (max) = 200

# %% [markdown]
# TV
#
# 1. Mean = 147.04
# 2. Standard Deviation (std) = 85.85
# 3. Minimum Value (min) = 0.70
# 4. Maximum Value (max) = 296.40

# %% [markdown]
# Radio
#
# 1. Mean = 23.26
# 2. Standard Deviation (std) = 14.85
# 3. Minimum Value (min) = 0
# 4. Maximum Value (max) = 49.60

# %% [markdown]
# Newspaper
#
# 1. Mean = 30.55
# 2. Standard Deviation (std) = 21.78
# 3. Minimum Value (min) = 0.30
# 4. Maximum Value (max) = 114

# %% [markdown]
# Sales
#
# 1. Mean = 14.02
# 2. Standard Deviation (std) = 5.22
# 3. Minimum Value (min) = 1.60
# 4. Maximum Value (max) = 27

# %% [markdown]
# # Normal Distribution Curve ---

# %%
ad_proj.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
sns.distplot(ad_proj["Unnamed: 0"], color="green")
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Density'>

# %%
sns.distplot(ad_proj["TV"], color="green")
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(ad_proj["radio"], color="green")
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %%
sns.distplot(ad_proj["newspaper"], color="green")
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %%
sns.distplot(ad_proj["sales"], color="green")
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# In the above case, we observed that the data is not normalized and it is skewed

# %% [markdown]
# # Correlation ---

# %%
ad_proj.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# From the above case, TV is highly correlated to sales

# %% [markdown]
# Correlation using Heatmap

# %%
plt.figure(figsize=(15,10))
sns.heatmap(ad_proj.corr(), annot=True, linewidth=0.5, linecolor="green", fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above case, there is no Correlation in the first column and let's remove/clean the data

# %%
ad_proj = ad_proj.iloc[:,1:]
ad_proj
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
ad_proj.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %%
import numpy as np
ad_proj.skew()
for col in ad_proj.skew().index:
    if col in ad_proj.columns:
        if ad_proj.skew().loc[col]>0.5:
            ad_proj[col] = np.sqrt(ad_proj[col])
        if ad_proj.skew().loc[col]<-0.5:
            ad_proj[col] = np.cbrt(ad_proj[col])
            
ad_proj.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.062388
# sales        0.407571
# dtype: float64

# %% [markdown]
# # Outlier Checking ---

# %%
ad_proj.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
sns.boxplot(ad_proj["TV"], color="green")
# Out:
# <AxesSubplot:xlabel='TV'>

# %%
sns.boxplot(ad_proj["radio"], color="green")
# Out:
# <AxesSubplot:xlabel='radio'>

# %%
sns.boxplot(ad_proj["newspaper"], color="green")
# Out:
# <AxesSubplot:xlabel='newspaper'>

# %%
sns.boxplot(ad_proj["sales"], color="green")
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# From the above case, we observe that there are not much outliers in the given dataset

# %% [markdown]
# # Checking Multicollinearity ---

# %%
x = ad_proj.iloc[:,:-1]
y = ad_proj.iloc[:,-1]
print(x.shape,y.shape)
# Out:
# (200, 3) (200,)

# %%
from sklearn.preprocessing import StandardScaler
stand_scale = StandardScaler()
x = stand_scale.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

train_x, test_x, train_y, test_y = train_test_split(x, y, random_state = 43, test_size = 0.20)

# %%
def fun(f):
    f.fit(train_x,train_y)
    pred = f.predict(test_x)
    print("Mean Squared Error =",mean_squared_error(test_y,pred))
    print("r2 score =",r2_score(test_y,pred))

# %% [markdown]
# # Cross Validation Score ---

# %%
from sklearn.model_selection import cross_val_score,KFold

def cvs(m):
    score = cross_val_score(m, x, y, cv = 5)
    print("Score =", score)
    print("Mean Score =", score.mean())

# %%
lin_reg = LinearRegression()
fun(lin_reg)
# Out:
# Mean Squared Error = 2.0637159157644644
# r2 score = 0.9283082849976607

# %%
cvs(lin_reg)
# Out:
# Score = [0.87809171 0.91744186 0.92982697 0.81591747 0.89538764]
# Mean Score = 0.8873331295445761

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.model_selection import GridSearchCV

param = {'alpha':[0.001,0.01,0.1,1]}
gd = GridSearchCV(Lasso(), param, cv=5)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'alpha': 0.1}

# %%
train_x.shape
# Out:
# (160, 3)

# %%
train_y.shape
# Out:
# (160,)

# %%
las = Lasso(alpha=0.1)
fun(las)
# Out:
# Mean Squared Error = 2.132902335940571
# r2 score = 0.9259048082984658

# %%
cvs(las)
# Out:
# Score = [0.88116506 0.91590917 0.93320601 0.81757164 0.89454442]
# Mean Score = 0.8884792606387284

# %%
param = {'alpha':[0.001,0.01,0.1,1]}
gd = GridSearchCV(Ridge(), param, cv=5)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'alpha': 1}

# %%
rid = Ridge(alpha=1)
fun(rid)
# Out:
# Mean Squared Error = 2.077730142907226
# r2 score = 0.9278214428065324

# %%
cvs(rid)
# Out:
# Score = [0.87811605 0.9169339  0.93091865 0.81523194 0.89575154]
# Mean Score = 0.8873904144766908

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

dtr = DecisionTreeRegressor()
svr = SVR()
knr = KNeighborsRegressor()

# %%
param = {'splitter':['best','random'],'max_features':['auto','sqrt','log2']}
gd = GridSearchCV(dtr, param, cv=5)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'max_features': 'auto', 'splitter': 'best'}

# %%
dtr = DecisionTreeRegressor(max_features='auto', splitter='best')
fun(dtr)
# Out:
# Mean Squared Error = 0.6949999999999996
# r2 score = 0.9758562980757122

# %%
cvs(dtr)
# Out:
# Score = [0.9650256  0.95728236 0.93589365 0.95019988 0.96571671]
# Mean Score = 0.9548236415037019

# %%
param = {'kernel':['linear','rbf','poly','sigmoid']}
gd = GridSearchCV(svr, param, cv=5)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'kernel': 'rbf'}

# %%
svr = SVR(kernel='rbf')
fun(svr)
# Out:
# Mean Squared Error = 2.198023364633081
# r2 score = 0.9236425598009766

# %%
cvs(svr)
# Out:
# Score = [0.88956967 0.94537894 0.93658432 0.80887294 0.92557096]
# Mean Score = 0.9011953652320344

# %%
param = {'n_neighbors':[7,5,9,11,15],'weights':['uniform','distance'],'algorithm':['auto','bell_tree','kd_tree','brute']}
gd = GridSearchCV(knr,param,cv=5)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}

# %%
knr = KNeighborsRegressor(algorithm='auto',n_neighbors=5,weights='distance')
fun(knr)
# Out:
# Mean Squared Error = 0.9720156770992027
# r2 score = 0.966233011836521

# %%
cvs(knr)
# Out:
# Score = [0.95010007 0.95692593 0.97000493 0.88818382 0.95254762]
# Mean Score = 0.9435524735733821

# %% [markdown]
# # Ensemble Method ---

# %%
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor

rfr = RandomForestRegressor()
abr = AdaBoostRegressor()
gbr = GradientBoostingRegressor()

# %%
param = {'n_estimators':[100,200,300,400,500],'random_state':[23,43,56,78,95]}
gd = GridSearchCV(rfr,param,cv=5)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'n_estimators': 200, 'random_state': 43}

# %%
rfr = RandomForestRegressor(n_estimators=200, random_state=43)
fun(rfr)
# Out:
# Mean Squared Error = 0.46832432500000065
# r2 score = 0.9837308159615924

# %%
cvs(rfr)
# Out:
# Score = [0.981525   0.9861421  0.9717841  0.96289394 0.98130071]
# Mean Score = 0.9767291716791513

# %%
param = {'n_estimators':[100,200,300,400,500],'random_state':[23,43,56,78,95]}
grid = GridSearchCV(abr,param,cv=5)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'n_estimators': 200, 'random_state': 23}

# %%
abr = AdaBoostRegressor(n_estimators=200, random_state=23)
fun(abr)
# Out:
# Mean Squared Error = 0.7841050135443546
# r2 score = 0.9727608665836626

# %%
cvs(abr)
# Out:
# Score = [0.96295558 0.97462004 0.95246944 0.94907524 0.95898231]
# Mean Score = 0.9596205229230295

# %%
param={'n_estimators':[100,200,300,400,500],'random_state':[23,43,56,78,95]}
grid = GridSearchCV(gbr,param,cv=5)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'n_estimators': 200, 'random_state': 23}

# %%
gbr = GradientBoostingRegressor(n_estimators=200,random_state=23)
fun(gbr)
# Out:
# Mean Squared Error = 0.358202317983614
# r2 score = 0.9875563597208844

# %%
cvs(gbr)
# Out:
# Score = [0.98172681 0.98663466 0.96740518 0.96911013 0.98655848]
# Mean Score = 0.9782870538069661

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
fun(xgb)
# Out:
# Mean Squared Error = 0.5679952711854224
# r2 score = 0.980268333062006

# %%
cvs(xgb)
# Out:
# Score = [0.97761645 0.97985384 0.93029924 0.96291738 0.97719774]
# Mean Score = 0.9655769324169171

# %% [markdown]
# # Model Saving ---

# %%
import pickle
filename = 'Advertising_sales.pkl'
pickle.dump(gbr, open(filename,'wb'))

# %% [markdown]
# # Conclusion ---

# %%
df = pd.DataFrame()
df['Actual'] = test_y
df['Predicted'] = gbr.predict(test_x)
df
# Out:
#      Actual  Predicted
# 56      5.5   5.996259
# 37     14.7  14.584483
# 67     13.4  12.522126
# 79     11.0  10.797485
# 80     11.8  12.067764
# 188    15.9  16.053316
# 183    26.2  25.383900
# 10      8.6   9.322942
# 128    24.7  23.221272
# 62     15.7  15.531299
# 65      9.3  10.066067
# 17     24.4  23.845067
# 133    19.6  19.944395
# 195     7.6   7.920138
# 146    13.2  12.721670
# 38     10.1  10.067153
# 173    11.7  11.530547
# 149    10.1   9.897050
# 93     22.2  22.786646
# 29     10.5  10.944774
# 0      22.1  20.927504
# 2       9.3   8.702123
# 122    11.6  11.067922
# 180    10.5  10.912868
# 95     16.9  17.325865
# 121     7.0   7.670853
# 185    22.6  21.957914
# 39     21.5  20.905184
# 66      9.5   8.209783
# 19     14.6  14.982827
# 11     17.4  16.657659
# 45     14.9  15.509164
# 41     17.1  17.942056
# 92     19.4  19.734287
# 168    17.1  17.102515
# 1      10.4  11.003788
# 57     13.2  13.054328
# 189     6.7   6.690307
# 151    11.6  11.819940
# ...

# %% [markdown]
# The r2 score in case of Gradient Boosting Regressor is the highest i.e 98.75 %
