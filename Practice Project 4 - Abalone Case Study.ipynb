# %% [markdown]
# # Abalone Case Study

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing all the required libraries

# %%
acs = pd.read_csv("abalone.csv")
acs
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
acs.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Rows = 4177 and Columns = 9

# %%
acs.shape
# Out:
# (4177, 9)

# %%
acs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
acs.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
acs.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
acs.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
acs.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

lab_enc = LabelEncoder()
acs["Sex"] = lab_enc.fit_transform(acs["Sex"])
acs
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
sns.countplot(acs["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# # Scatterplot ---

# %%
acs.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
sns.scatterplot(x="Sex", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Rings'>

# %%
sns.scatterplot(x="Length", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Rings'>

# %%
sns.scatterplot(x="Diameter", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Rings'>

# %%
sns.scatterplot(x="Height", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Rings'>

# %%
sns.scatterplot(x="Whole weight", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Shucked weight", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Viscera weight", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Shell weight", y="Rings", data=acs)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Rings'>

# %% [markdown]
# # Correlation ---

# %%
acs.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(acs.corr(), annot=True, linewidth=0.5, linecolor='green', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Describing Dataset ---

# %%
acs.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
plt.figure(figsize=(15,20))
sns.heatmap(round(acs.describe()[1:].transpose(),2), linewidth=1, annot=True, fmt='f')
plt.xticks(fontsize=15)
plt.yticks(fontsize=10)
plt.title("Variables Summary")
plt.show()

# %% [markdown]
# # Dataset Outcome ---

# %% [markdown]
# Sex
#
# 1. Mean = 1.050000
# 2. Standard Deviation (std) = 0.820000
# 3. Minimum Value (min) = 0.000
# 4. Maximum Value (max) = 2.000

# %% [markdown]
# Length
#
# 1. Mean = 0.523992
# 2. Standard Deviation (std) = 0.120093
# 3. Minimum Value (min) = 0.075
# 4. Maximum Value (max) = 0.815

# %% [markdown]
# Diameter
#
# 1. Mean = 0.407881
# 2. Standard Deviation (std) = 0.099240
# 3. Minimum Value (min) = 0.055
# 4. Maximum Value (max) = 0.650

# %% [markdown]
# Height
#
# 1. Mean = 0.139516
# 2. Standard Deviation (std) = 0.041827
# 3. Minimum Value (min) = 0.000
# 4. Maximum Value (max) = 1.130

# %% [markdown]
# Whole Weight
#
# 1. Mean = 0.828742
# 2. Standard Deviation (std) = 0.490389
# 3. Minimum Value (min) = 0.002
# 4. Maximum Value (max) = 2.825500

# %% [markdown]
# Shucked Weight
#
# 1. Mean = 0.359367
# 2. Standard Deviation (std) = 0.221963
# 3. Minimum Value (min) = 0.001
# 4. Maximum Value (max) = 1.488000

# %% [markdown]
# Viscera Weight
#
# 1. Mean = 0.238831
# 2. Standard Deviation (std) = 0.139203
# 3. Minimum Value (min) = 0.000500
# 4. Maximum Value (max) = 0.760000

# %% [markdown]
# Shell Weight
#
# 1. Mean = 0.238831
# 2. Standard Deviation (std) = 0.139203
# 3. Minimum Value (min) = 0.001500
# 4. Maximum Value (max) = 1.005000

# %% [markdown]
# # Outlier Checking ---

# %%
collist = acs.columns.values
ncol= 30
nrows= 15
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(acs[collist[i]], color="blue", orient="v")
    plt.tight_layout()

# %% [markdown]
# # Normal Distribution Curve ---

# %%
acs.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
sns.distplot(acs["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Density'>

# %%
sns.distplot(acs["Length"])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(acs["Diameter"])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(acs["Height"])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(acs["Whole weight"])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(acs["Shucked weight"])
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
sns.distplot(acs["Viscera weight"])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(acs["Shell weight"])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
sns.distplot(acs["Rings"])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [markdown]
# As we observed in the above case that the data is not normalised and the data is skewed

# %%
acs.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
from scipy.stats import zscore
z = np.abs(zscore(acs))
z.shape
# Out:
# (4177, 9)

# %% [markdown]
# Rows = 4177 and Columns = 9

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
acs_new = acs[(z<3).all(axis=1)]
acs_new.shape
# Out:
# (4027, 9)

# %% [markdown]
# Rows = 4027 and Columns = 9

# %%
loss_percentage = (4177-4027)/4177*100
print(loss_percentage)
# Out:
# 3.5910940866650707

# %% [markdown]
# # Checking Multicollinearity ---

# %%
x = acs_new.iloc[:,:-1]
y = acs_new.iloc[:,-1]

# %%
import scipy.stats as st
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as viff

def calc_vif(x1):
    vif_acs = pd.DataFrame()
    vif_acs["Variables"] = x1.columns
    vif_acs['VIF Factor'] = [viff(x1.values,i) for i in range(x1.shape[1])]
    vif_acs.index+=1
    return(vif_acs)

calc_vif(x)
# Out:
#         Variables  VIF Factor
# 1             Sex    2.586539
# 2          Length  711.017756
# 3        Diameter  762.862946
# 4          Height   92.050181
# 5    Whole weight  441.600560
# 6  Shucked weight  108.511496
# 7  Viscera weight   65.669278
# 8    Shell weight   94.849108

# %%
acs_new.drop(['Length','Shucked weight'], axis=1, inplace=True)
x = acs_new.iloc[:,:-1]

# %%
from sklearn.preprocessing import power_transform

x = power_transform(x, method="yeo-johnson")
x
# Out:
# array([[ 1.13432919, -0.54337947, -1.15893308, -0.57513463, -0.68803217,
#         -0.58635376],
#        [ 1.13432919, -1.40113174, -1.28040611, -1.35404959, -1.33285416,
#         -1.33271691],
#        [-1.31306782,  0.03716259, -0.12830502, -0.18449788, -0.24037305,
#         -0.08021413],
#        ...,
#        [ 1.13432919,  0.70592133,  1.94363286,  0.85343427,  1.08965131,
#          0.66363183],
#        [-1.31306782,  0.8377131 ,  0.28606972,  0.69738476,  0.87642835,
#          0.57752029],
#        [ 1.13432919,  1.85550496,  1.62558351,  2.14577531,  1.73214622,
#          1.85675543]])

# %%
from sklearn.preprocessing import StandardScaler

stand_sc = StandardScaler()
x = stand_sc.fit_transform(x)
x
# Out:
# array([[ 1.13432919, -0.54337947, -1.15893308, -0.57513463, -0.68803217,
#         -0.58635376],
#        [ 1.13432919, -1.40113174, -1.28040611, -1.35404959, -1.33285416,
#         -1.33271691],
#        [-1.31306782,  0.03716259, -0.12830502, -0.18449788, -0.24037305,
#         -0.08021413],
#        ...,
#        [ 1.13432919,  0.70592133,  1.94363286,  0.85343427,  1.08965131,
#          0.66363183],
#        [-1.31306782,  0.8377131 ,  0.28606972,  0.69738476,  0.87642835,
#          0.57752029],
#        [ 1.13432919,  1.85550496,  1.62558351,  2.14577531,  1.73214622,
#          1.85675543]])

# %% [markdown]
# # Using Regression Models ---

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor  
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVR
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
lin_reg = LinearRegression()

x_train, x_test, y_train, y_test=train_test_split(x, y, random_state=43, test_size=0.20)
lin_reg.fit(x_train, y_train)
pred_train = lin_reg.predict(x_train)
pred_test = lin_reg.predict(x_test)
print("Mean Squared Error", mean_squared_error(pred_test,y_test))
print(r2_score(pred_test, y_test))
# Out:
# Mean Squared Error 4.333030596308985
# -0.12337947937634453

# %% [markdown]
# # Lasso and Ridge ---

# %%
from sklearn.linear_model import Lasso,Ridge

las = Lasso(alpha=0.0001)
las.fit(x_train, y_train)
las.score(x_train, y_train)
# Out:
# 0.45281255318966096

# %%
las.coef_
# Out:
# array([-3.55764638e-03, -4.41849591e-01,  7.71014382e-01, -2.26887282e+00,
#         1.15777455e-01,  3.64093860e+00])

# %%
rid = Ridge(alpha=0.0001)
rid.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
rid.score(x_train, y_train)
# Out:
# 0.4528127552388833

# %%
from sklearn.linear_model import ElasticNet
enr = ElasticNet(alpha=0.0001)
enr.fit(x_train, y_train)
enr.score(x_train, y_train)
# Out:
# 0.4528122895444777

# %%
kernellist = ['linear','rbf','poly']
for i in kernellist:
    svr = SVR(kernel=i)
    svr.fit(x_train, y_train)
    pred = svr.predict(x_test)
    print(mean_squared_error(y_test,pred))
# Out:
# 4.54234536635636
# 4.094636907324739
# 5.590894503558537

# %%
from sklearn.tree import DecisionTreeRegressor
dec_tree = DecisionTreeRegressor(criterion='mse')
dec_tree.fit(x_train, y_train)
print("DTC Score",dec_tree.score(x_train, y_train))

pred_dtc=dec_tree.predict(x_test)
print("r2 Score",r2_score(y_test, pred_dtc))
print("Mean_Squared_Error", mean_squared_error(y_test, pred_dtc))
# Out:
# DTC Score 1.0
# r2 Score 0.01182995535051612
# Mean_Squared_Error 7.859801488833747

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn.fit(x_train, y_train)
print("KN Score",knn.score(x_train, y_train))

pred_knn = knn.predict(x_test)
print("r2 Score",r2_score(y_test, pred_knn))
print("Mean_Squared_Error", mean_squared_error(y_test, pred_knn))
# Out:
# KN Score 0.6315578104380475
# r2 Score 0.4130940673723186
# Mean_Squared_Error 4.668188585607941

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(x_train, y_train)
print("SVR Score",svr.score(x_train, y_train))
pred_svr=svr.predict(x_test)
print("r2 Score",r2_score(y_test, pred_svr))
print("Mean_Squared_Error", mean_squared_error(y_test, pred_svr))
# Out:
# SVR Score 0.4915526236794009
# r2 Score 0.4852035968996343
# Mean_Squared_Error 4.094636907324739

# %%
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor()
sgd_reg.fit(x_train,y_train)
print("SGD Score",sgd_reg.score(x_train, y_train))
pred_sgd = sgd_reg.predict(x_test)
print("r2 Score",r2_score(y_test, pred_sgd))
print("Mean_Squared_Error", mean_squared_error(y_test, pred_sgd))
# Out:
# SGD Score 0.44980301992127314
# r2 Score 0.4510998707210576
# Mean_Squared_Error 4.365894389014781

# %%
from sklearn.ensemble import RandomForestRegressor
ran_for = RandomForestRegressor(n_estimators=100,random_state=42)
ran_for.fit(x_train, y_train)
print("RF Score",ran_for.score(x_train, y_train))
pred_rf = ran_for.predict(x_test)
print("r2 Score",r2_score(y_test, pred_rf))
print("Mean_Squared_Error", mean_squared_error(y_test, pred_rf))
# Out:
# RF Score 0.9272718194268706
# r2 Score 0.48851944123022095
# Mean_Squared_Error 4.068263027295285

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_boost = AdaBoostRegressor(n_estimators=50, random_state=42)
ada_boost.fit(x_train, y_train)
print("AB Score", ada_boost.score(x_train, y_train))
pred_ada = ada_boost.predict(x_test)
print("r2 Score", r2_score(y_test, pred_ada))
print("Mean_Squared_Error", mean_squared_error(y_test, pred_ada))
# Out:
# AB Score 0.38017793875199013
# r2 Score 0.3792624198836949
# Mean_Squared_Error 4.937281981770444

# %% [markdown]
# # Saving the Best Model ---

# %%
import joblib
joblib.dump(dec_tree,'dtrmodel.obj')
dtrloadmodel=joblib.load('dtrmodel.obj')
dtrloadmodel.predict(x_test)
# Out:
# array([12., 12., 14., 15.,  9.,  8.,  8.,  8., 10., 10.,  9., 10., 16.,
#        10.,  8., 15.,  7., 11., 12., 11., 10.,  7., 10., 10., 10.,  8.,
#        10., 11.,  6.,  9.,  8.,  8.,  8., 10.,  8., 10.,  9.,  7., 11.,
#        13., 10., 11., 10., 14., 13., 14., 14.,  8., 12.,  8., 10., 10.,
#         9.,  9.,  9., 15., 10.,  9.,  8., 13., 15.,  9., 11., 10.,  7.,
#        13.,  7., 12., 15.,  6.,  9.,  8., 14., 12., 16.,  8.,  6.,  6.,
#        11.,  8., 11.,  9.,  9., 10., 12.,  7., 12.,  8.,  8.,  9., 10.,
#         8.,  9.,  8., 11., 18., 10., 13., 14., 11., 12.,  9., 10.,  7.,
#         8.,  5., 11., 10.,  7.,  8., 10.,  9., 16.,  8., 10., 10., 11.,
#         9., 14., 10., 11.,  8.,  8., 11., 10.,  7.,  9., 17.,  9., 12.,
#        11.,  5., 10., 11.,  8., 10., 18., 12., 10.,  6.,  9., 15.,  8.,
#         8., 12.,  9.,  7.,  5.,  8.,  5., 15.,  8., 13., 10., 10.,  9.,
#        10., 11., 19., 11., 10., 12.,  8.,  6., 11.,  8., 12.,  8.,  8.,
# ...

# %% [markdown]
# Above all the above case, Decision Tree Regressor has the highest score/accuracy equal to 100 %
