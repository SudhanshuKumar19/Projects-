# %% [markdown]
# # Global Power Plant Database Project

# %%
# Importing all the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
global_proj = pd.read_csv("database_IND.csv")

# %%
global_proj
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# From the above case, we clearly observed that the given data contains the null values that needs to be removed

# %%
global_proj.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
global_proj.shape
# Out:
# (908, 25)

# %% [markdown]
# Number of Rows = 908 and Columns = 25

# %%
global_proj.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   908.000000  862.000000  862.000000          0.0          528.000000
# mean    321.046378   21.196189   77.447848          NaN         1996.876894
# std     580.221767    6.248627    4.907260          NaN           17.047817
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.837500   16.771575   74.258975          NaN         1988.000000
# 50%      60.000000   21.778300   76.719250          NaN         2000.000000
# 75%     388.125000   25.516375   79.441475          NaN         2011.250000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  520.0           384.000000
# mean       NaN                 2018.0          2304.059202
# std        NaN                    0.0          3794.767492
# ...

# %% [markdown]
# From the above case, the data is highly spread

# %%
global_proj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   908 non-null    object
#  1   country_long              908 non-null    object
#  2   name                      908 non-null    object
#  3   gppd_idnr                 908 non-null    object
#  4   capacity_mw               908 non-null    float64
#  5   latitude                  862 non-null    float64
#  6   longitude                 862 non-null    float64
#  7   primary_fuel              908 non-null    object
#  8   other_fuel1               199 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        528 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
global_proj.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %% [markdown]
# From the above case, the given dataset contains a lot of null values that must be removed

# %%
global_proj.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_data_source       object
# estimated_generation_gwh    float64
# dtype: object

# %%
a_cols=[]

for i in global_proj.columns:
    if global_proj[i].dtype =="object":
        a_cols.append(i)

# %%
a_cols
# Out:
# ['country',
#  'country_long',
#  'name',
#  'gppd_idnr',
#  'primary_fuel',
#  'other_fuel1',
#  'other_fuel2',
#  'owner',
#  'source',
#  'url',
#  'geolocation_source',
#  'generation_data_source']

# %%
global_proj["country"].unique()
# Out:
# array(['IND'], dtype=object)

# %%
global_proj["country_long"].unique()
# Out:
# array(['India'], dtype=object)

# %%
global_proj["name"].unique()
# Out:
# array(['ACME Solar Tower', 'ADITYA CEMENT WORKS',
#        'AES Saurashtra Windfarms', 'AGARTALA GT', 'AKALTARA TPP',
#        'AKRIMOTA LIG', 'ALIYAR', 'ALLAIN DUHANGAN', 'ALMATTI DAM',
#        'AMAR KANTAK', 'AMARAVATI TPP', 'ANANDPUR SAHIB ST-I&II',
#        'ANAPARA "C"', 'ANDHRA', 'ANOOPGARH ST I&II', 'ANPARA', 'ANTA GT',
#        'ANUPPUR', 'ANUPUR TPP', 'ARVINDNAGAR SUGAR', 'ASHOKNAGAR MILL',
#        'ATHANI SUGAR', 'AURAIYA GT', 'AVANTHA BHANDAR TPP',
#        'AWARPUR CEMENT PLANT', 'Abhijeet', 'Amarsar Solar Power Plant',
#        'Anabura Wind Farm', 'Ananthapur - Meil Solar Power Plant',
#        'Andrha Lake Wind Farm', 'Anikkadavu Wind Farm',
#        'Arasinagundi Wind Farm', 'Askandra - DREPL Solar Power Plant',
#        'Askandra - Electromech Maritech Solar Power Plant',
#        'Askandra - Finehope Solar Power Plant',
#        'Askandra - Khaya Solar Power Plant',
#        'Askandra - Newton Solar Power Plant',
#        'Askandra - Saidham Solar Power Plant',
# ...

# %%
global_proj["name"].nunique()
# Out:
# 908

# %%
global_proj["gppd_idnr"].unique()
# Out:
# array(['WRI1020239', 'WRI1019881', 'WRI1026669', 'IND0000001',
#        'IND0000002', 'IND0000003', 'IND0000004', 'IND0000005',
#        'IND0000006', 'IND0000007', 'IND0000008', 'IND0000009',
#        'IND0000010', 'IND0000011', 'IND0000012', 'IND0000013',
#        'IND0000014', 'WRI1019996', 'IND0000015', 'WRI1019938',
#        'WRI1019939', 'WRI1019904', 'IND0000016', 'IND0000017',
#        'WRI1019940', 'WRI1020238', 'WRI1026104', 'WRI1026069',
#        'WRI1026105', 'WRI1026768', 'WRI1026347', 'WRI1026068',
#        'WRI1026106', 'WRI1026107', 'WRI1026108', 'WRI1026109',
#        'WRI1026110', 'WRI1026111', 'WRI1026112', 'IND0000018',
#        'IND0000019', 'WRI1019905', 'IND0000020', 'IND0000021',
#        'IND0000022', 'IND0000023', 'IND0000025', 'IND0000024',
#        'WRI1019941', 'WRI1019882', 'IND0000026', 'IND0000027',
#        'IND0000028', 'IND0000029', 'IND0000030', 'IND0000031',
#        'IND0000032', 'WRI1019883', 'IND0000033', 'IND0000034',
# ...

# %%
global_proj["gppd_idnr"].nunique()
# Out:
# 908

# %%
global_proj["commissioning_year"].value_counts()
# Out:
# 2013.0    28
# 2015.0    26
# 2012.0    23
# 2016.0    21
# 2014.0    17
#           ..
# 1939.0     1
# 1927.0     1
# 1949.0     1
# 1956.0     1
# 1969.0     1
# Name: commissioning_year, Length: 73, dtype: int64

# %%
global_proj["owner"].value_counts()
# Out:
# Jk Cement ltd                               4
# Sterling Agro Industries ltd.               4
# Acc Acc ltd                                 4
# Tata Power Solar Systems Limited (TPREL)    3
# SWPPL                                       3
#                                            ..
# Vikram Vikram cement                        1
# KS Oils                                     1
# Solaer                                      1
# Rswm Rswm ltd                               1
# Mahatma Power ltd                           1
# Name: owner, Length: 280, dtype: int64

# %%
global_proj["owner"].nunique()
# Out:
# 280

# %%
global_proj["source"].value_counts()
# Out:
# Central Electricity Authority                       520
# CDM                                                 124
# Lancosola                                            10
# National Renewable Energy Laboratory                  8
# National Thermal Power Corporation (NTPC)             6
#                                                    ...
# CleanEnerg teLeanenergy                               1
# Sunflag Co ltd                                        1
# Lokmangal Lokmangal group                             1
# Gujarat Industries Power Company Limited (GIPCL)      1
# Janki Corp ltd                                        1
# Name: source, Length: 191, dtype: int64

# %%
global_proj["source"].nunique()
# Out:
# 191

# %%
global_proj["geolocation_source"].value_counts()
# Out:
# WRI                                     766
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
global_proj["geolocation_source"].nunique()
# Out:
# 3

# %%
global_proj["generation_data_source"].value_counts()
# Out:
# Central Electricity Authority    450
# Name: generation_data_source, dtype: int64

# %%
global_proj["generation_data_source"].nunique()
# Out:
# 1

# %%
global_proj.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %% [markdown]
# From the above case, a lot of null values are present

# %%
from sklearn.impute import SimpleImputer

simp = SimpleImputer(missing_values=np.NaN,strategy='most_frequent')
for i in ['latitude','longitude','other_fuel1','commissioning_year','owner','geolocation_source','year_of_capacity_data','generation_data_source']:
    global_proj[i] = simp.fit_transform(global_proj[i].values.reshape(-1,1))

# %%
global_proj
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         Oil         NaN
# ...

# %% [markdown]
# From the above case, we observed that fuel 2 and fuel 3 contains only NaN value and that's why we will remove them

# %%
global_proj["other_fuel1"].unique()
# Out:
# array(['Oil', 'Cogeneration', 'Gas'], dtype=object)

# %%
a = []
for i in global_proj["gppd_idnr"]:
    a.append(i[0:3])

# %%
global_proj["gppd_prefix"] = a

# %%
global_proj.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                   0
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year            0
# owner                         0
# source                        0
# url                           0
# geolocation_source            0
# wepp_id                     908
# year_of_capacity_data         0
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source        0
# estimated_generation_gwh    908
# gppd_prefix                   0
# dtype: int64

# %%
global_proj['year_of_capacity_data'] = simp.fit_transform(global_proj['year_of_capacity_data'].values.reshape(-1,1))
for i in ['generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']:
    global_proj[i] = global_proj[i].replace(np.NaN,0)

# %%
global_proj
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         Oil         NaN
# ...

# %% [markdown]
# From the above case, the Column estimated_generation_gwh doesn't have any value and so we will delete it

# %%
global_proj.drop(["estimated_generation_gwh"],axis=1,inplace=True)

# %%
global_proj.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1                 0
# other_fuel2               907
# other_fuel3               908
# commissioning_year          0
# owner                       0
# source                      0
# url                         0
# geolocation_source          0
# wepp_id                   908
# year_of_capacity_data       0
# generation_gwh_2013         0
# generation_gwh_2014         0
# generation_gwh_2015         0
# generation_gwh_2016         0
# generation_gwh_2017         0
# generation_data_source      0
# gppd_prefix                 0
# dtype: int64

# %% [markdown]
# From the above case, it is clear that we have removed the null values from most of the Columns

# %%
a_cols=[]

for i in global_proj.columns:
    if global_proj[i].dtypes == "object":
        a_cols.append(i)

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
for i in a_cols:
    global_proj[i] = lab.fit_transform(global_proj[i])

# %% [markdown]
# # EDA

# %% [markdown]
# # Scatterplot ---

# %%
global_proj.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_data_source',
#        'gppd_prefix'],
#       dtype='object')

# %%
sns.scatterplot(x="country", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='country', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="country_long", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='country_long', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="name", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='name', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="gppd_idnr", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='gppd_idnr', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="capacity_mw", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="latitude", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="longitude", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="primary_fuel", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="other_fuel1", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='other_fuel1', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="other_fuel2", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='other_fuel2', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="commissioning_year", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='commissioning_year', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="owner", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='owner', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="source", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='source', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="url", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='url', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="geolocation_source", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="year_of_capacity_data", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='year_of_capacity_data', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="generation_gwh_2013", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2013', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="generation_gwh_2014", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="generation_gwh_2015", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="generation_gwh_2016", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="generation_gwh_2017", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="generation_data_source", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='generation_data_source', ylabel='capacity_mw'>

# %%
sns.scatterplot(x="gppd_prefix", y="capacity_mw", data = global_proj, color="green")
# Out:
# <AxesSubplot:xlabel='gppd_prefix', ylabel='capacity_mw'>

# %% [markdown]
# # Countplot ---

# %% [markdown]
# Since we have a lot of columns that's why we will use a loop to plot all the data

# %%
for i in a_cols:
    sns.countplot(global_proj[i])
    plt.show()

# %%
global_proj.describe()
# Out:
#        country  country_long       name  gppd_idnr  capacity_mw    latitude  \
# count    908.0         908.0  908.00000  908.00000   908.000000  908.000000
# mean       0.0           0.0  453.50000  453.50000   321.046378   21.084948
# std        0.0           0.0  262.26132  262.26132   580.221767    6.107146
# min        0.0           0.0    0.00000    0.00000     0.000000    8.168900
# 25%        0.0           0.0  226.75000  226.75000    16.837500   17.057825
# 50%        0.0           0.0  453.50000  453.50000    60.000000   21.278850
# 75%        0.0           0.0  680.25000  680.25000   388.125000   25.183775
# max        0.0           0.0  907.00000  907.00000  4760.000000   34.649000
#
#         longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# count  908.000000    908.000000   908.000000   908.000000  ...
# mean    77.156237      3.205947     1.995595     0.998899  ...
# std      4.945215      2.281339     0.081214     0.033186  ...
# ...

# %% [markdown]
# From the above case, it shows that the data is widely spread

# %% [markdown]
# # Correlation ---

# %%
global_proj.corr()
# Out:
#                         country  country_long      name  gppd_idnr  \
# country                     NaN           NaN       NaN        NaN
# country_long                NaN           NaN       NaN        NaN
# name                        NaN           NaN  1.000000   0.336792
# gppd_idnr                   NaN           NaN  0.336792   1.000000
# capacity_mw                 NaN           NaN  0.059870  -0.334308
# latitude                    NaN           NaN -0.135744  -0.107985
# longitude                   NaN           NaN  0.010089  -0.375394
# primary_fuel                NaN           NaN  0.038752   0.607373
# other_fuel1                 NaN           NaN -0.074643   0.001812
# other_fuel2                 NaN           NaN -0.045414   0.001330
# other_fuel3                 NaN           NaN       NaN        NaN
# commissioning_year          NaN           NaN -0.040006   0.476840
# owner                       NaN           NaN  0.098944   0.630597
# ...

# %% [markdown]
# From the above case, it is clear that some columns dont have correlation

# %%
# Heatmap Using Correlation

# %%
plt.figure(figsize=(16,16))
sns.heatmap(global_proj.corr(), annot=True, linewidth=0.5, linecolor='green', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Let's drop some of the values that are totally not required

# %%
global_proj.drop(['country','country_long','wepp_id','gppd_idnr','other_fuel2','other_fuel3','year_of_capacity_data','generation_data_source'],inplace=True,axis=1)

# %%
global_proj
# Out:
#      name  capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0       0          2.5   28.1839    73.2407             6            2
# 1       1         98.0   24.7663    74.6090             1            2
# 2       2         39.2   21.9038    69.3732             7            2
# 3       3        135.0   23.8712    91.3602             2            2
# 4       4       1800.0   21.9603    82.4091             1            2
# ..    ...          ...       ...        ...           ...          ...
# 903   903       1600.0   16.2949    77.3568             1            2
# 904   904          3.0   12.8932    78.1654             6            2
# 905   905         25.5   15.2758    75.5811             7            2
# 906   906         80.0   24.3500    73.7477             1            2
# 907   907         16.5    9.9344    77.4768             7            2
#
#      commissioning_year  owner  source  url  geolocation_source  \
# ...

# %%
global_proj.drop(["name","url"],inplace=True,axis=1)

# %%
global_proj
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            2
# 1           98.0   24.7663    74.6090             1            2
# 2           39.2   21.9038    69.3732             7            2
# 3          135.0   23.8712    91.3602             2            2
# 4         1800.0   21.9603    82.4091             1            2
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            2
# 904          3.0   12.8932    78.1654             6            2
# 905         25.5   15.2758    75.5811             7            2
# 906         80.0   24.3500    73.7477             1            2
# 907         16.5    9.9344    77.4768             7            2
#
#      commissioning_year  owner  source  geolocation_source  \
# 0                2011.0    229     109                   1
# 1                2013.0    258     174                   2
# ...

# %% [markdown]
# # Checking Outliers ---

# %%
global_proj.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'source', 'geolocation_source',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'gppd_prefix'],
#       dtype='object')

# %%
sns.boxplot(global_proj.capacity_mw, color="green")
# Out:
# <AxesSubplot:xlabel='capacity_mw'>

# %%
sns.boxplot(global_proj.latitude, color="green")
# Out:
# <AxesSubplot:xlabel='latitude'>

# %%
sns.boxplot(global_proj.longitude, color="green")
# Out:
# <AxesSubplot:xlabel='longitude'>

# %%
sns.boxplot(global_proj.primary_fuel, color="green")
# Out:
# <AxesSubplot:xlabel='primary_fuel'>

# %%
sns.boxplot(global_proj.other_fuel1, color="green")
# Out:
# <AxesSubplot:xlabel='other_fuel1'>

# %%
sns.boxplot(global_proj.commissioning_year, color="green")
# Out:
# <AxesSubplot:xlabel='commissioning_year'>

# %%
sns.boxplot(global_proj.owner, color="green")
# Out:
# <AxesSubplot:xlabel='owner'>

# %%
sns.boxplot(global_proj.source, color="green")
# Out:
# <AxesSubplot:xlabel='source'>

# %%
sns.boxplot(global_proj.geolocation_source, color="green")
# Out:
# <AxesSubplot:xlabel='geolocation_source'>

# %%
sns.boxplot(global_proj.generation_gwh_2013, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2013'>

# %%
sns.boxplot(global_proj.generation_gwh_2014, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014'>

# %%
sns.boxplot(global_proj.generation_gwh_2015, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015'>

# %%
sns.boxplot(global_proj.generation_gwh_2016, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016'>

# %%
sns.boxplot(global_proj.generation_gwh_2017, color="green")
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017'>

# %%
sns.boxplot(global_proj.gppd_prefix, color="green")
# Out:
# <AxesSubplot:xlabel='gppd_prefix'>

# %% [markdown]
# From the above case, there are a lot of outliers that has to be be removed

# %%
global_proj.skew()
# Out:
# capacity_mw             3.193257
# latitude               -0.093609
# longitude               1.118449
# primary_fuel            0.471141
# other_fuel1           -20.464435
# commissioning_year     -1.779021
# owner                   1.366078
# source                  1.829145
# geolocation_source     -2.161710
# generation_gwh_2013     5.158053
# generation_gwh_2014     4.989441
# generation_gwh_2015     5.264211
# generation_gwh_2016     4.988235
# generation_gwh_2017     4.983065
# gppd_prefix             0.294357
# dtype: float64

# %% [markdown]
# From the above case, the dataset is highly skewed

# %% [markdown]
# # Correlation ---

# %%
global_proj.corr()
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.057801   0.217022     -0.377783
# latitude                0.057801  1.000000   0.050511     -0.023407
# longitude               0.217022  0.050511   1.000000     -0.369505
# primary_fuel           -0.377783 -0.023407  -0.369505      1.000000
# other_fuel1             0.002672  0.035502   0.026090      0.004902
# commissioning_year      0.012518  0.035378  -0.138390      0.145487
# owner                  -0.310560 -0.069336  -0.286716      0.284055
# source                 -0.241701  0.061728  -0.211786      0.053609
# geolocation_source      0.204698 -0.190605   0.220798     -0.482803
# generation_gwh_2013     0.776258  0.067649   0.155235     -0.273831
# generation_gwh_2014     0.827206  0.070407   0.162076     -0.286188
# generation_gwh_2015     0.853262  0.066108   0.175572     -0.291437
# generation_gwh_2016     0.886996  0.059540   0.197305     -0.304274
# ...

# %% [markdown]
# Since, other_fuel1 doesn't has much correlation and that's why we will remove it

# %%
global_proj.drop(["other_fuel1"],inplace=True,axis=1)

# %% [markdown]
# # EDA

# %% [markdown]
# # Normal Distribution Curve ---

# %%
global_proj.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'primary_fuel',
#        'commissioning_year', 'owner', 'source', 'geolocation_source',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'gppd_prefix'],
#       dtype='object')

# %%
# Using loop method to show all the plots

# %%
for i in global_proj.columns:
    sns.distplot(global_proj[i], color="green")
    plt.show()

# %% [markdown]
# From the above case, the data is highly skewed and that's why it must be removed

# %%
from scipy.stats import zscore

z = zscore(global_proj)

# %%
global_proj = global_proj[(z<3).all(axis=1)]

# %%
global_proj.shape
# Out:
# (857, 14)

# %% [markdown]
# Number of Rows = 857 and Columns = 14

# %%
x = global_proj.iloc[:,1:]
y = global_proj.iloc[:,1]

# %%
from sklearn.preprocessing import power_transform

x = power_transform(x,method="yeo-johnson")

# %%
from sklearn.preprocessing import StandardScaler

ms = StandardScaler()
x = ms.fit_transform(x)

# %% [markdown]
# # Linear Regression ---

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split

x_train = x
y_train = y
x_test = x
y_test = y
r_state = 0
max_r2 = 0
lr = LinearRegression()
for i in range(0,1000):
    tr_x,t_x,tr_y,t_y=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(tr_x,tr_y)
    pred=lr.predict(t_x)
    if r2_score(t_y,pred)>max_r2:
        x_train = tr_x
        x_test = t_x
        y_train = tr_y
        y_test = t_y
        r_state = i
        max_r2 = r2_score(t_y,pred)
print("At Random State",i,"max_r2 is",max_r2)
# Out:
# At Random State 999 max_r2 is 0.9999970657717817

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred = f.predict(x_test)
    print("MSE=",mean_squared_error(y_test,pred))
    print("r2 score=",r2_score(y_test,pred))

# %% [markdown]
# # Cross Valuation Score ---

# %%
from sklearn.model_selection import cross_val_score,KFold

def cvs(m):
    cv1 = KFold(n_splits=5,shuffle=True)
    score = cross_val_score(m,x,y,cv=cv1,scoring='r2')
    print("Cross Val Score",score)
    print(score.mean())

# %%
from sklearn.model_selection import GridSearchCV

def hypertuning(params,model):
    gd = GridSearchCV(model,params,cv=5)
    gd.fit(x,y)
    print(gd.best_params_)

# %%
lr_params = {'fit_intercept':[True,False],'normalize':[True,False],'copy_X':[True,False],'n_jobs':[None,1,2,3]}
hypertuning(lr_params,lr)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': True}

# %%
lr = LinearRegression(copy_X=True,fit_intercept=True,n_jobs=None,normalize=True)

fun(lr)
# Out:
# MSE= 0.00011552116714292746
# r2 score= 0.9999970657717817

# %%
cvs(lr)
# Out:
# Cross Val Score [0.99999614 0.99999667 0.99999604 0.99999598 0.99999667]
# 0.9999962996141866

# %%
CVS=[99.99]
r2=[99.99]
Model = ["Linear Regression"]

# %%
l = Lasso()
params_lasso = {
    'alpha':[0.001,0.01,0.1,1],
    'fit_intercept':[True,False],
    'normalize':[True,False],
    'copy_X':[True,False]
}
hypertuning(params_lasso,l)
# Out:
# {'alpha': 0.001, 'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
l = Lasso(alpha=0.001,copy_X=True,fit_intercept=True,normalize=False)

fun(l)
# Out:
# MSE= 0.00013047650340470228
# r2 score= 0.9999966859074612

# %%
cvs(l)
# Out:
# Cross Val Score [0.99999601 0.99999631 0.99999629 0.99999572 0.99999619]
# 0.9999961021921978

# %%
CVS.append(99.99)
r2.append(99.99)
Model.append("Lasso")

# %%
R = Ridge()
params_ridge = {
    'alpha':[0.001,0.01,0.1,1],
    'fit_intercept':[True,False],
    'normalize':[True,False],
    'copy_X':[True,False]
}
hypertuning(params_ridge,R)
# Out:
# {'alpha': 0.001, 'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
R = Ridge(alpha=0.001,copy_X=True,fit_intercept=True,normalize=False)

fun(R)
# Out:
# MSE= 0.00011555873263554275
# r2 score= 0.9999970648176213

# %%
cvs(R)
# Out:
# Cross Val Score [0.99999616 0.999996   0.99999668 0.99999662 0.99999597]
# 0.9999962857781319

# %%
CVS.append(99.99)
r2.append(99.99)
Model.append("Ridge")

# %%
en = ElasticNet()
params_en = {
    'alpha':[0.001,0.01,0.1,1],
    'fit_intercept':[True,False],
    'normalize':[True,False],
    'copy_X':[True,False]
}
hypertuning(params_en,en)
# Out:
# {'alpha': 0.001, 'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
en = ElasticNet(alpha=0.001,copy_X=True,fit_intercept=True,normalize=False)

fun(en)
# Out:
# MSE= 0.00014829448493970792
# r2 score= 0.9999962333321842

# %%
cvs(en)
# Out:
# Cross Val Score [0.99999621 0.9999944  0.99999669 0.99999608 0.99999608]
# 0.9999958922324147

# %%
CVS.append(99.99)
r2.append(99.99)
Model.append("ElasticNet")

# %%
from sklearn.svm import SVR

params_svr = {
    'kernel':['poly','linear','rbf','sigmoid'],'degree':[1,3,5,7],'gamma':['auto','scale'],'shrinking':[True,False]}
hypertuning(params_svr,SVR())
# Out:
# {'degree': 1, 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}

# %%
svr = SVR(degree=1,gamma='auto',kernel='linear',shrinking=True)

fun(svr)
cvs(svr)
# Out:
# MSE= 0.004074473601696227
# r2 score= 0.9998965087030169
# Cross Val Score [0.99989    0.99990132 0.99990408 0.99987999 0.99990034]
# 0.9998951451000124

# %%
CVS.append(99.98)
r2.append(99.98)
Model.append("SVR")

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
params_dtr = {'criterion':['mse','friedman_mse','mae'],'splitter':['random','best'],'max_depth':[None,1,2,3],'min_samples_split':[2,3,4]}
hypertuning(params_dtr,dtr)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 4, 'splitter': 'best'}

# %%
dtr = DecisionTreeRegressor(criterion='friedman_mse',max_depth=None,min_samples_split=3,splitter='best')

fun(dtr)
cvs(dtr)
# Out:
# MSE= 0.006916830930232582
# r2 score= 0.9998243130588245
# Cross Val Score [0.99985681 0.9998803  0.99990707 0.9997357  0.9998691 ]
# 0.9998497985873283

# %%
CVS.append(99.98)
r2.append(99.98)
Model.append("Decision Tree Regressor")

# %%
from sklearn.neighbors import KNeighborsRegressor

knc = KNeighborsRegressor()
params_knc = {'n_neighbors':[5,7,9,11],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute'],'leaf_size':[30,40,50]}
hypertuning(params_knc,knc)
# Out:
# {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 5, 'weights': 'distance'}

# %%
knc = KNeighborsRegressor(algorithm='brute',leaf_size=30,n_neighbors=5,weights='distance')

fun(knc)
cvs(knc)
# Out:
# MSE= 1.2764991832837422
# r2 score= 0.9675770249141136
# Cross Val Score [0.94416252 0.965096   0.95359538 0.95818504 0.94769927]
# 0.953747641161687

# %%
CVS.append(95.61)
r2.append(96.76)
Model.append("K Neighbor Regressor")

# %% [markdown]
# # Ensemble Method ---

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,HistGradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor

rf = RandomForestRegressor()
etr = ExtraTreeRegressor()
ada = AdaBoostRegressor()
Gd = GradientBoostingRegressor()
HGd = HistGradientBoostingRegressor()

# %%
params_rf = {'n_estimators':[10,20,30,50,100],
           'criterion':['mae','mse'],
           'max_depth':[None,1,2,3],
           'min_samples_split':[2,3,4]}
hypertuning(params_rf,rf)
# Out:
# {'criterion': 'mae', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}

# %%
rf = RandomForestRegressor(criterion='mae',max_depth=None,min_samples_split=2,n_estimators=100)

fun(rf)
cvs(rf)
# Out:
# MSE= 0.003760090567366055
# r2 score= 0.9999044940064334
# Cross Val Score [0.99984946 0.999942   0.9999395  0.9999685  0.99994857]
# 0.9999296053362003

# %%
CVS.append(99.99)
r2.append(99.99)
Model.append("Random Forest Regressor")

# %%
params_etr = {'criterion':['mse','friedman_mse','mae'],
            'splitter':['random','best'],
            'max_depth':[None,1,2,3],
            'min_samples_split':[2,3,4]}
hypertuning(params_etr,etr)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 3, 'splitter': 'best'}

# %%
etr = ExtraTreeRegressor(criterion='friedman_mse',max_depth=None,min_samples_split=4,splitter='best')

fun(etr)
cvs(etr)
# Out:
# MSE= 0.007740589974160265
# r2 score= 0.9998033896463321
# Cross Val Score [0.99987147 0.99991464 0.99981951 0.99986474 0.99992353]
# 0.9998787766179283

# %%
CVS.append(99.98)
r2.append(99.98)
Model.append("Extra Tree Regressor")

# %%
params_ada = {'n_estimators':[10,20,30,50],'learning_rate':[1,0.9,0.8],'loss':['linear', 'square', 'exponential'],'random_state':[43,33,56]}
hypertuning(params_ada,ada)
# Out:
# {'learning_rate': 1, 'loss': 'square', 'n_estimators': 50, 'random_state': 56}

# %%
ada = AdaBoostRegressor(learning_rate=1,loss='square',n_estimators=50,random_state=56)

fun(ada)
cvs(ada)
# Out:
# MSE= 0.04474994919792859
# r2 score= 0.9988633549422204
# Cross Val Score [0.99888835 0.99915498 0.9991995  0.99908472 0.99891449]
# 0.999048405725207

# %%
CVS.append(99.90)
r2.append(99.88)
Model.append("Ada Boost Regressor")

# %%
params_Gd = {'n_estimators':[50,100,150],'learning_rate':[1,0.9,0.8],'loss':['ls', 'lad', 'huber', 'quantile'],'criterion':['friedman_mse', 'mse', 'mae']}
hypertuning(params_Gd,Gd)
# Out:
# {'criterion': 'friedman_mse', 'learning_rate': 0.8, 'loss': 'ls', 'n_estimators': 150}

# %%
Gd = GradientBoostingRegressor(criterion='mse',learning_rate=0.8,loss='ls',n_estimators=100)

fun(Gd)
cvs(Gd)
# Out:
# MSE= 0.03249157815167488
# r2 score= 0.9991747165664432
# Cross Val Score [0.99881684 0.99870474 0.99808896 0.99854868 0.99937064]
# 0.9987059731134756

# %%
CVS.append(99.87)
r2.append(99.91)
Model.append("Gradient Boosting Regressor")

# %%
params_hgd = {'loss':['least_squares','least_absolute_deviation','poisson'],'learning_rate':[0.1,0.2,0.3],'max_iter':[100,50,70],'max_leaf_nodes':[None,1,21,31,41]}
hypertuning(params_hgd,HGd)
# Out:
# {'learning_rate': 0.2, 'loss': 'least_squares', 'max_iter': 70, 'max_leaf_nodes': None}

# %%
HGd = HistGradientBoostingRegressor(learning_rate=0.2,loss='least_squares',max_iter=70,max_leaf_nodes=None)

fun(HGd)
cvs(HGd)
# Out:
# MSE= 0.018084010332694148
# r2 score= 0.9995406676133066
# Cross Val Score [0.99924716 0.99924842 0.99878807 0.99932714 0.99914701]
# 0.9991515571373689

# %%
CVS.append(99.91)
r2.append(99.95)
Model.append("Hist Gradient Boosting Regressorr")

# %%
output = pd.DataFrame()
output["Models"] = Model
output["CVS"] = CVS
output["r2"] = r2
diff=[]

for i in range(0,len(r2)):
    diff.append(r2[i]-CVS[i])
output["Diff."] = diff
output.index+=1

# %%
output
# Out:
#                                Models    CVS     r2  Diff.
# 1                   Linear Regression  99.99  99.99   0.00
# 2                               Lasso  99.99  99.99   0.00
# 3                               Ridge  99.99  99.99   0.00
# 4                          ElasticNet  99.99  99.99   0.00
# 5                                 SVR  99.98  99.98   0.00
# 6            Decision Tree Classifier  99.98  99.98   0.00
# 7               K Neighbor Classifier  95.61  96.76   1.15
# 8             Decision Tree Regressor  99.98  99.98   0.00
# 9                K Neighbor Regressor  95.61  96.76   1.15
# 10            Random Forest Regressor  99.99  99.99   0.00
# 11               Extra Tree Regressor  99.98  99.98   0.00
# 12                Ada Boost Regressor  99.90  99.88  -0.02
# 13        Gradient Boosting Regressor  99.87  99.91   0.04
# 14  Hist Gradient Boosting Regressorr  99.91  99.95   0.04

# %%
# According to the table above, the best model has to be Random Forest Regressor hence saving it plus there are also others models that have great accuracy

# %% [markdown]
# # Model Saving ----

# %%
import pickle

filename = "Capacity_Prediction.pkl"
pickle.dump(rf,open(filename,'wb'))

# %%
predict=rf.predict(x_test)

# %%
output_rf = pd.DataFrame()
output_rf["Actual"] = y_test
output_rf["Predicted"] = predict
output_rf
# Out:
#       Actual  Predicted
# 516  18.8829  18.874966
# 761  12.3003  12.309870
# 84   19.5132  19.536894
# 657  18.7695  18.766300
# 216  32.2417  32.225177
# ..       ...        ...
# 870  13.6576  13.783493
# 479  19.0004  19.000162
# 18   23.0655  23.045839
# 457  32.0041  31.961196
# 756  21.0864  21.091750
#
# [172 rows x 2 columns]

# %%
# Let's save the dataframe in csv file

# %%
output.to_csv("Capacity_prediction.csv")

# %% [markdown]
# # Classifiers ---

# %%
x = global_proj.drop(["primary_fuel"],axis=1)
y = global_proj["primary_fuel"]

# %%
from sklearn.preprocessing import power_transform

x = power_transform(x,method="yeo-johnson")

# %%
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler()
x = sc.fit_transform(x)

# %%
from imblearn.over_sampling import SMOTE

smt = SMOTE()
x,y = smt.fit_resample(x,y)

# %%
x.shape,y.shape
# Out:
# ((1936, 13), (1936,))

# %% [markdown]
# # Logistic Regression ---

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

x_train = x
y_train = y
x_test = x
y_test = y
r_state = 0
max_acc = 0
lr = LogisticRegression()
for i in range(0,2000):
    tr_x,t_x,tr_y,t_y=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(tr_x,tr_y)
    pred=lr.predict(t_x)
    if accuracy_score(t_y,pred)>max_acc:
        x_train = tr_x
        x_test = t_x
        y_train = tr_y
        y_test = t_y
        r_state = i
        max_acc = accuracy_score(t_y,pred)
print("At Random State",i,"max_acc is",max_acc)
# Out:
# At Random State 1999 max_acc is 0.7938144329896907

# %% [markdown]
# # Cross Validation Score ---

# %%
from sklearn.model_selection import cross_val_score,KFold

def cvs(m):
    cv1 = KFold(n_splits=5,shuffle=True)
    score = cross_val_score(m,x,y,cv=cv1,scoring='accuracy')
    print("Cross Val score",score)
    print(score.mean())

# %%
from sklearn.model_selection import GridSearchCV

def hypertuning(params,model):
    gd = GridSearchCV(model,params,cv=5)
    gd.fit(x,y)
    print(gd.best_params_)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print("Accuracy Score",accuracy_score(y_test,pred))
    print("Confusion Matrix \n",confusion_matrix(y_test,pred))
    print("Classification Report \n",classification_report(y_test,pred))

# %%
fun(lr)
cvs(lr)
# Out:
# Accuracy Score 0.7938144329896907
# Confusion Matrix
#  [[50  0  0  0  0  0  0  5]
#  [ 5 25  0  3  6  0  0  1]
#  [ 4 14 11  3  8  3  0  2]
#  [ 0  6  1 44  3  0  0  0]
#  [ 0  0  0  2 40  0  0  0]
#  [ 8  1  0  2  0 37  0  1]
#  [ 0  0  0  0  0  2 46  0]
#  [ 0  0  0  0  0  0  0 55]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82        55
#            1       0.54      0.62      0.58        40
#            2       0.92      0.24      0.39        45
#            3       0.81      0.81      0.81        54
#            4       0.70      0.95      0.81        42
#            5       0.88      0.76      0.81        49
#            6       1.00      0.96      0.98        48
#            7       0.86      1.00      0.92        55
#
#     accuracy                           0.79       388
#    macro avg       0.81      0.78      0.77       388
# weighted avg       0.81      0.79      0.78       388
#
# ...

# %%
CVS = [71.23]
Acc = [79.38]
Model = ["Logistic Regression"]

# %%
from sklearn.svm import SVC

params_svc = {
    'kernel':['poly','linear','rbf','sigmoid'],'degree':[1,3,5,7],'gamma':['auto','scale'],'shrinking':[True,False]}
hypertuning(params_svc,SVC())
# Out:
# {'degree': 7, 'gamma': 'scale', 'kernel': 'poly', 'shrinking': True}

# %%
svc = SVC(kernel='poly',degree=7,gamma='scale',shrinking=True)

fun(svc)
cvs(svc)
# Out:
# Accuracy Score 0.9201030927835051
# Confusion Matrix
#  [[53  0  0  0  0  0  0  2]
#  [ 3 33  1  1  1  0  0  1]
#  [ 0  5 35  0  0  4  0  1]
#  [ 0  7  3 44  0  0  0  0]
#  [ 0  0  0  0 42  0  0  0]
#  [ 0  2  0  0  0 47  0  0]
#  [ 0  0  0  0  0  0 48  0]
#  [ 0  0  0  0  0  0  0 55]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95        55
#            1       0.70      0.82      0.76        40
#            2       0.90      0.78      0.83        45
#            3       0.98      0.81      0.89        54
#            4       0.98      1.00      0.99        42
#            5       0.92      0.96      0.94        49
#            6       1.00      1.00      1.00        48
#            7       0.93      1.00      0.96        55
#
#     accuracy                           0.92       388
#    macro avg       0.92      0.92      0.92       388
# weighted avg       0.92      0.92      0.92       388
#
# ...

# %%
CVS.append(91.37)
Acc.append(92.01)
Model.append("SVC")

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
params_dtc = {'criterion':['gini','entropy'],'splitter':['random','best'],'max_depth':[None,1,2,3],'min_samples_split':[2,3,4]}
hypertuning(params_dtc,dtc)
# Out:
# {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 2, 'splitter': 'best'}

# %%
dtc = DecisionTreeClassifier(criterion='entropy',max_depth=None,min_samples_split=2,splitter='best')

fun(dtc)
cvs(dtc)
# Out:
# Accuracy Score 0.904639175257732
# Confusion Matrix
#  [[54  1  0  0  0  0  0  0]
#  [ 1 31  3  3  1  1  0  0]
#  [ 1  3 34  4  1  2  0  0]
#  [ 0  4  4 44  1  1  0  0]
#  [ 0  3  0  0 39  0  0  0]
#  [ 0  1  1  0  1 46  0  0]
#  [ 0  0  0  0  0  0 48  0]
#  [ 0  0  0  0  0  0  0 55]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        55
#            1       0.72      0.78      0.75        40
#            2       0.81      0.76      0.78        45
#            3       0.86      0.81      0.84        54
#            4       0.91      0.93      0.92        42
#            5       0.92      0.94      0.93        49
#            6       1.00      1.00      1.00        48
#            7       1.00      1.00      1.00        55
#
#     accuracy                           0.90       388
#    macro avg       0.90      0.90      0.90       388
# weighted avg       0.90      0.90      0.90       388
#
# ...

# %%
CVS.append(88.48)
Acc.append(90.04)
Model.append("Decision Tree Classifier")

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
params_knn = {'n_neighbors':[5,7,9,11],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute'],'leaf_size':[30,40,50]}
hypertuning(params_knn,knn)
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'weights': 'distance'}

# %%
knn = KNeighborsClassifier(algorithm='auto',leaf_size=30,n_neighbors=5,weights='distance')

fun(knn)
cvs(knn)
# Out:
# Accuracy Score 0.9175257731958762
# Confusion Matrix
#  [[54  1  0  0  0  0  0  0]
#  [ 4 29  1  1  4  0  0  1]
#  [ 0  5 37  0  0  3  0  0]
#  [ 0  4  5 45  0  0  0  0]
#  [ 0  0  0  1 41  0  0  0]
#  [ 0  0  2  0  0 47  0  0]
#  [ 0  0  0  0  0  0 48  0]
#  [ 0  0  0  0  0  0  0 55]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96        55
#            1       0.74      0.72      0.73        40
#            2       0.82      0.82      0.82        45
#            3       0.96      0.83      0.89        54
#            4       0.91      0.98      0.94        42
#            5       0.94      0.96      0.95        49
#            6       1.00      1.00      1.00        48
#            7       0.98      1.00      0.99        55
#
#     accuracy                           0.92       388
#    macro avg       0.91      0.91      0.91       388
# weighted avg       0.92      0.92      0.92       388
#
# ...

# %%
CVS.append(89.30)
Acc.append(91.75)
Model.append("KNN Classifier")

# %% [markdown]
# # Ensemble Method ---

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,HistGradientBoostingClassifier
from sklearn.tree import ExtraTreeClassifier

rf = RandomForestClassifier()
etc = ExtraTreeClassifier()
ada = AdaBoostClassifier()
Gd = GradientBoostingClassifier()
HGd = HistGradientBoostingClassifier()

# %%
params_rf = {'n_estimators':[10,20,30,50],
           'criterion':['gini', 'entropy'],
           'max_depth':[None,1,2,3],
           'min_samples_split':[2,3,4]}
hypertuning(params_rf,rf)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}

# %%
rf = RandomForestClassifier(criterion='gini',max_depth=None,min_samples_split=4,n_estimators=30)

fun(rf)
cvs(rf)
# Out:
# Accuracy Score 0.9355670103092784
# Confusion Matrix
#  [[54  1  0  0  0  0  0  0]
#  [ 1 31  4  1  2  0  0  1]
#  [ 0  4 38  0  0  3  0  0]
#  [ 0  3  2 48  0  1  0  0]
#  [ 0  0  0  1 41  0  0  0]
#  [ 0  0  0  0  0 49  0  0]
#  [ 0  0  1  0  0  0 47  0]
#  [ 0  0  0  0  0  0  0 55]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        55
#            1       0.79      0.78      0.78        40
#            2       0.84      0.84      0.84        45
#            3       0.96      0.89      0.92        54
#            4       0.95      0.98      0.96        42
#            5       0.92      1.00      0.96        49
#            6       1.00      0.98      0.99        48
#            7       0.98      1.00      0.99        55
#
#     accuracy                           0.94       388
#    macro avg       0.93      0.93      0.93       388
# weighted avg       0.94      0.94      0.94       388
#
# ...

# %%
CVS.append(91.99)
Acc.append(93.55)
Model.append("Random Forest Classifier")

# %%
from sklearn.tree import ExtraTreeClassifier

etc = ExtraTreeClassifier()
params_etc = {'criterion':['gini','entropy'],
            'splitter':['random','best'],
            'max_depth':[None,1,2,3],
            'min_samples_split':[2,3,4]}
hypertuning(params_etc,etc)
# Out:
# {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 2, 'splitter': 'best'}

# %%
etc = ExtraTreeClassifier(criterion='gini',max_depth=None,min_samples_split=4,splitter='best')

fun(etc)
cvs(etc)
# Out:
# Accuracy Score 0.884020618556701
# Confusion Matrix
#  [[53  2  0  0  0  0  0  0]
#  [ 1 32  3  3  1  0  0  0]
#  [ 0  4 34  5  0  2  0  0]
#  [ 0  7  4 42  1  0  0  0]
#  [ 0  2  0  1 39  0  0  0]
#  [ 1  2  2  1  0 43  0  0]
#  [ 0  1  1  0  0  0 45  1]
#  [ 0  0  0  0  0  0  0 55]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        55
#            1       0.64      0.80      0.71        40
#            2       0.77      0.76      0.76        45
#            3       0.81      0.78      0.79        54
#            4       0.95      0.93      0.94        42
#            5       0.96      0.88      0.91        49
#            6       1.00      0.94      0.97        48
#            7       0.98      1.00      0.99        55
#
#     accuracy                           0.88       388
#    macro avg       0.88      0.88      0.88       388
# weighted avg       0.89      0.88      0.89       388
#
# ...

# %%
CVS.append(87.34)
Acc.append(88.40)
Model.append("Extra Tree Classifier")

# %%
params_ada={'n_estimators':[10,20,30,50],'learning_rate':[1,0.9,0.8],'algorithm':['SAMME', 'SAMME.R'],'random_state':[43,33,56]}
hypertuning(params_ada,ada)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.8, 'n_estimators': 50, 'random_state': 43}

# %%
ada = AdaBoostClassifier(algorithm='SAMME',learning_rate=0.9,n_estimators=50,random_state=43)

fun(ada)
cvs(ada)
# Out:
# Accuracy Score 0.5876288659793815
# Confusion Matrix
#  [[ 0  0  0  0  0 53  0  2]
#  [ 0 17  0  5 12  5  0  1]
#  [ 0 10  0 26  1  7  0  1]
#  [ 0  2  0 35  4 13  0  0]
#  [ 0  3  0  2 37  0  0  0]
#  [ 0  6  0  0  0 43  0  0]
#  [ 0  0  0  0  0  2 41  5]
#  [ 0  0  0  0  0  0  0 55]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        55
#            1       0.45      0.42      0.44        40
#            2       0.00      0.00      0.00        45
#            3       0.51      0.65      0.57        54
#            4       0.69      0.88      0.77        42
#            5       0.35      0.88      0.50        49
#            6       1.00      0.85      0.92        48
#            7       0.86      1.00      0.92        55
#
#     accuracy                           0.59       388
#    macro avg       0.48      0.59      0.52       388
# weighted avg       0.48      0.59      0.52       388
#
# ...

# %%
CVS.append(62.86)
Acc.append(58.76)
Model.append("AdaBoostCLassifier")

# %%
output1 = pd.DataFrame()
output1['Models'] = Model
output1["CVS"] = CVS
output1["Acc"] = Acc
diff = []

for i in range(0,len(Acc)):
    diff.append(Acc[i]-CVS[i])
output1["Diff."]=diff

# %%
output1
# Out:
#                      Models    CVS    Acc  Diff.
# 0       Logistic Regression  71.23  79.38   8.15
# 1                       SVC  91.37  92.01   0.64
# 2  Decision Tree Classifier  88.48  90.04   1.56
# 3            KNN Classifier  89.30  91.75   2.45
# 4  Random Forest Classifier  91.99  93.55   1.56
# 5     Extra Tree Classifier  87.34  88.40   1.06
# 6        AdaBoostCLassifier  62.86  58.76  -4.10

# %%
#From above, the best model is Random Forest Classifier with the Highest Accuracy

# %% [markdown]
# # Model Saving ---

# %%
import pickle

filename = "PrimaryFuel_Prediction.pkl"
pickle.dump(rf,open(filename,'wb'))

# %%
predict = rf.predict(x_test)

# %%
output_rf = pd.DataFrame()
output_rf["Actual"] = y_test
output_rf["Predicted"] = predict

output_rf
# Out:
#       Actual  Predicted
# 271        1          1
# 1296       4          4
# 550        1          1
# 258        7          7
# 1316       4          4
# ...      ...        ...
# 1051       0          0
# 1087       2          2
# 1555       5          5
# 1219       2          2
# 1855       7          7
#
# [388 rows x 2 columns]

# %%
# Let's save the dataframe in csv file

# %%
output.to_csv("PrimaryFuel_Prediction.csv")

# %%
# The Accuracy is case of Random Forest Classifier is the highest i.e. 93.55%
